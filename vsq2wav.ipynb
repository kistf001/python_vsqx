# %%
from pywinauto.application import Application, findwindows
import pywinauto
import time
import nameUtility as nu

directory = "H:/Dataset"

name_list = nu.fileNameSpliter().vsqx.scan(directory)

print(name_list)

for vvvv in name_list:

    fileName = "H:\\Dataset\\"+ vvvv +".vsqx"
    fileNameWave = "H:\\Dataset\\" + vvvv

    # Start VOCALOID 4
    app = Application(backend="uia").start("C:/Program Files (x86)/Vocaloid4FE/VOCALOID4.exe", retry_interval=6)

    # Wait 10 Second
    time.sleep(10)

    vsqx = app.Dialog

    vsqx.set_focus()
    vsqx.maximize()

    # Open vsqx File
    pywinauto.keyboard.send_keys("%{F},{O}")

    vsqx_open = vsqx.child_window(title="열기", control_type="Window")
    vsqx_open_ComboBox = vsqx_open.child_window(title="파일 이름(N):", auto_id="1148", control_type="ComboBox")
    vsqx_open_ComboBox.Edit.set_text(fileName)

    vsqx_open_button = vsqx_open.child_window(title="열기(O)", auto_id="1", control_type="Button")
    vsqx_open_button.click()
    
    # Wait 7 Second
    time.sleep(7)

    # Extract Wave file
    pywinauto.keyboard.send_keys("%{F},{E},{W}")

    vsqx_exportWaveFile = vsqx.child_window(title="Export Wave File", control_type="Window")
    vsqx_exportWaveFile_samplingRate = vsqx_exportWaveFile.child_window(title="Sampling Rate(S)", auto_id="1405", control_type="ComboBox")
    vsqx_exportWaveFile_samplingRate.select("48000")
    vsqx_exportWaveFile_OK = vsqx_exportWaveFile.child_window(title="OK", auto_id="1", control_type="Button")
    vsqx_exportWaveFile_OK.click()

    vsqx_findFolder = vsqx.child_window(title="폴더 찾아보기", control_type="Window")
    vsqx_findFolder_edit = vsqx_findFolder.child_window(title="폴더(F):", auto_id="14148", control_type="Edit")
    vsqx_findFolder_edit.set_text(fileNameWave)
    vsqx_findFolder_button = vsqx_findFolder.child_window(title="확인", auto_id="1", control_type="Button")
    vsqx_findFolder_button.click()
    
    # Wait 3 Second
    time.sleep(3)

    #vsqx.kill()
    vsqx.set_focus()
    app.Dialog.print_control_identifiers()
    pywinauto.keyboard.send_keys("%{F},{X}")
    
    print(vvvv)
# Out:
# ['20191225_022421', '20191225_022423', '20191225_022425', '20191225_022428', '20191225_022430', '20191225_022432', '20191225_022433', '20191225_022435', '20191225_022437', '20191225_022438', '20191225_022440', '20191225_022441', '20191225_022443', '20191225_022445', '20191225_022446', '20191225_022448', '20191225_022450', '20191225_022451', '20191225_022453', '20191225_022454', '20191225_022456', '20191225_022458', '20191225_022459', '20191225_022501', '20191225_022502', '20191225_022504', '20191225_022506', '20191225_022507', '20191225_022509', '20191225_022510', '20191225_022512', '20191225_022513', '20191225_022515', '20191225_022517', '20191225_022518', '20191225_022520', '20191225_022522', '20191225_022523', '20191225_022525', '20191225_022526', '20191225_022528', '20191225_022530', '20191225_022531', '20191225_022533', '20191225_022535', '20191225_022536', '20191225_022538', '20191225_022540', '20191225_022541', '20191225_022543', '20191225_022544', '20191225_022546', '20191225_022547', '20191225_022549', '20191225_022551', '20191225_022552', '20191225_022554', '20191225_022556', '20191225_022557', '20191225_022559', '20191225_022600', '20191225_022602', '20191225_022604', '20191225_022606', '20191225_022607', '20191225_022609', '20191225_022611', '20191225_022613', '20191225_022614', '20191225_022616', '20191225_022618', '20191225_022620', '20191225_022622', '20191225_022624', '20191225_022626', '20191225_022628', '20191225_022629', '20191225_022631', '20191225_022633', '20191225_022635', '20191225_022636', '20191225_022638', '20191225_022640', '20191225_022641', '20191225_022643', '20191225_022645', '20191225_022647', '20191225_022648', '20191225_022650', '20191225_022652', '20191225_022654', '20191225_022655', '20191225_022657', '20191225_022659', '20191225_022700', '20191225_022702', '20191225_022704', '20191225_022706', '20191225_022707', '20191225_022709', '20191225_022711', '20191225_022713', '20191225_022714', '20191225_022716', '20191225_022718', '20191225_022720', '20191225_022722', '20191225_022723', '20191225_022725', '20191225_022726', '20191225_022728', '20191225_022730', '20191225_022731', '20191225_022733', '20191225_022735', '20191225_022737', '20191225_022739', '20191225_022740', '20191225_022743', '20191225_022745', '20191225_022746', '20191225_022748', '20191225_022750', '20191225_022752', '20191225_022754', '20191225_022756', '20191225_022758', '20191225_022800', '20191225_022801', '20191225_022803', '20191225_022804', '20191225_022806', '20191225_022808', '20191225_022809', '20191225_022811', '20191225_022813', '20191225_022815', '20191225_022817', '20191225_022819', '20191225_022821', '20191225_022822', '20191225_022824', '20191225_022826', '20191225_022827', '20191225_022829', '20191225_022831', '20191225_022832', '20191225_022834', '20191225_022836', '20191225_022837', '20191225_022839', '20191225_022840', '20191225_022842', '20191225_022843', '20191225_022845', '20191225_022847', '20191225_022848', '20191225_022850', '20191225_022851', '20191225_022853']
# Control Identifiers:
#
# Dialog - 'VOCALOID4 Editor - [MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]]'    (L-8, T-8, R1288, B1002)
# ['Dialog', 'VOCALOID4 Editor - [MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]]Dialog', 'VOCALOID4 Editor - [MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]]', 'Dialog0', 'Dialog1']
# child_window(title="VOCALOID4 Editor - [MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]]", control_type="Window")
#    |
#    | Dialog - 'VOCALOID Editor'    (L520, T418, R761, B577)
#    | ['Dialog2', 'VOCALOID Editor', 'VOCALOID EditorDialog']
#    | child_window(title="VOCALOID Editor", control_type="Window")
#    |    |
#    |    | Button - '확인'    (L663, T537, R738, B560)
#    |    | ['Button', '확인Button', '확인', 'Button0', 'Button1']
#    |    | child_window(title="확인", auto_id="2", control_type="Button")
#    |    |
#    |    | Image - ''    (L549, T472, R581, B504)
#    |    | ['300.00Image', 'Image']
#    |    | child_window(auto_id="20", control_type="Image")
#    |    |
#    |    | Static - 'Failed to export wave file!'    (L590, T482, R725, B497)
#    |    | ['Failed to export wave file!Static', 'Failed to export wave file!', 'Static', 'Static0', 'Static1']
#    |    | child_window(title="Failed to export wave file!", auto_id="65535", control_type="Text")
#    |    |
#    |    | TitleBar - ''    (L528, T421, R753, B449)
#    |    | ['TitleBar', '300.00TitleBar', 'TitleBar0', 'TitleBar1']
#    |    |    |
#    |    |    | Button - '닫기'    (L0, T0, R0, B0)
#    |    |    | ['Button2', '닫기', '닫기Button', '닫기0', '닫기1', '닫기Button0', '닫기Button1']
#    |    |    | child_window(title="닫기", control_type="Button")
#    |
#    | Pane - '작업 영역'    (L0, T88, R1280, B994)
#    | ['Pane', '작업 영역', '작업 영역Pane', 'Pane0', 'Pane1']
#    | child_window(title="작업 영역", auto_id="59648", control_type="Pane")
#    |    |
#    |    | Dialog - 'MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]'    (L-8, T57, R1288, B1002)
#    |    | ['MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]', 'Dialog3', 'MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]Dialog']
#    |    | child_window(title="MUSICAL EDITOR - Part [BTHGND24Y9RMATF6]", auto_id="65281", control_type="Window")
#    |    |    |
#    |    |    | Pane - ''    (L0, T88, R1280, B994)
#    |    |    | ['Pane2', ' 0 : 1 : 000Pane', ' 0 : 1 : 000Pane0', ' 0 : 1 : 000Pane1']
#    |    |    | child_window(auto_id="59648", control_type="Pane")
#    |    |    |    |
#    |    |    |    | ScrollBar - ''    (L1263, T120, R1280, B768)
#    |    |    |    | ['1/16ScrollBar', 'ScrollBar', 'ScrollBar0', 'ScrollBar1', '1/16ScrollBar0', '1/16ScrollBar1']
#    |    |    |    | child_window(auto_id="1027", control_type="ScrollBar")
#    |    |    |    |    |
#    |    |    |    |    | Button - '위쪽 스크롤 화살표'    (L1263, T120, R1280, B137)
#    |    |    |    |    | ['Button3', '위쪽 스크롤 화살표', '위쪽 스크롤 화살표Button', '위쪽 스크롤 화살표0', '위쪽 스크롤 화살표1', '위쪽 스크롤 화살표Button0', '위쪽 스크롤 화살표Button1']
#    |    |    |    |    | child_window(title="위쪽 스크롤 화살표", auto_id="UpButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - '페이지 위로'    (L1263, T137, R1280, B213)
#    |    |    |    |    | ['Button4', '페이지 위로', '페이지 위로Button']
#    |    |    |    |    | child_window(title="페이지 위로", auto_id="UpPageButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Thumb - '위치'    (L1263, T213, R1280, B435)
#    |    |    |    |    | ['위치', '위치Thumb', 'Thumb', '위치0', '위치1', '위치Thumb0', '위치Thumb1', 'Thumb0', 'Thumb1']
#    |    |    |    |    | child_window(title="위치", auto_id="ScrollbarThumb", control_type="Thumb")
#    |    |    |    |    |
#    |    |    |    |    | Button - '페이지 아래로'    (L1263, T435, R1280, B751)
#    |    |    |    |    | ['Button5', '페이지 아래로Button', '페이지 아래로', '페이지 아래로Button0', '페이지 아래로Button1', '페이지 아래로0', '페이지 아래로1']
#    |    |    |    |    | child_window(title="페이지 아래로", auto_id="DownPageButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - '아래쪽 스크롤 화살표'    (L1263, T751, R1280, B768)
#    |    |    |    |    | ['Button6', '아래쪽 스크롤 화살표Button', '아래쪽 스크롤 화살표', '아래쪽 스크롤 화살표Button0', '아래쪽 스크롤 화살표Button1', '아래쪽 스크롤 화살표0', '아래쪽 스크롤 화살표1']
#    |    |    |    |    | child_window(title="아래쪽 스크롤 화살표", auto_id="DownButton", control_type="Button")
#    |    |    |    |
#    |    |    |    | ScrollBar - ''    (L85, T768, R1196, B785)
#    |    |    |    | ['Failed to export wave file!ScrollBar', 'ScrollBar2']
#    |    |    |    | child_window(auto_id="1028", control_type="ScrollBar")
#    |    |    |    |    |
#    |    |    |    |    | Button - '왼쪽 스크롤 화살표'    (L85, T768, R102, B785)
#    |    |    |    |    | ['Button7', '왼쪽 스크롤 화살표', '왼쪽 스크롤 화살표Button', '왼쪽 스크롤 화살표0', '왼쪽 스크롤 화살표1', '왼쪽 스크롤 화살표Button0', '왼쪽 스크롤 화살표Button1']
#    |    |    |    |    | child_window(title="왼쪽 스크롤 화살표", auto_id="UpButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Thumb - '위치'    (L102, T768, R110, B785)
#    |    |    |    |    | ['위치2', '위치Thumb2', 'Thumb2']
#    |    |    |    |    | child_window(title="위치", auto_id="ScrollbarThumb", control_type="Thumb")
#    |    |    |    |    |
#    |    |    |    |    | Button - '페이지 오른쪽으로'    (L110, T768, R1179, B785)
#    |    |    |    |    | ['Button8', '페이지 오른쪽으로Button', '페이지 오른쪽으로', '페이지 오른쪽으로Button0', '페이지 오른쪽으로Button1', '페이지 오른쪽으로0', '페이지 오른쪽으로1']
#    |    |    |    |    | child_window(title="페이지 오른쪽으로", auto_id="DownPageButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - '오른쪽 스크롤 화살표'    (L1179, T768, R1196, B785)
#    |    |    |    |    | ['Button9', '오른쪽 스크롤 화살표', '오른쪽 스크롤 화살표Button', '오른쪽 스크롤 화살표0', '오른쪽 스크롤 화살표1', '오른쪽 스크롤 화살표Button0', '오른쪽 스크롤 화살표Button1']
#    |    |    |    |    | child_window(title="오른쪽 스크롤 화살표", auto_id="DownButton", control_type="Button")
#    |    |    |
#    |    |    | TitleBar - ''    (L0, T65, R1280, B87)
#    |    |    | ['TitleBar2', 'SONG POS.TitleBar']
#    |    |
#    |    | Dialog - 'TRACK EDITOR - 20191225_022421.vsqx'    (L0, T88, R1276, B379)
#    |    | ['Dialog4', 'TRACK EDITOR - 20191225_022421.vsqxDialog', 'TRACK EDITOR - 20191225_022421.vsqx']
#    |    | child_window(title="TRACK EDITOR - 20191225_022421.vsqx", auto_id="65280", control_type="Window")
#    |    |    |
#    |    |    | Pane - ''    (L8, T119, R1268, B371)
#    |    |    | ['Pane3', ' 0 : 1 : 000Pane2']
#    |    |    | child_window(auto_id="59648", control_type="Pane")
#    |    |    |    |
#    |    |    |    | ScrollBar - ''    (L1251, T174, R1268, B283)
#    |    |    |    | ['1/16ScrollBar2', 'ScrollBar3']
#    |    |    |    | child_window(auto_id="1027", control_type="ScrollBar")
#    |    |    |    |    |
#    |    |    |    |    | Button - '위쪽 스크롤 화살표'    (L1251, T174, R1268, B191)
#    |    |    |    |    | ['Button10', '위쪽 스크롤 화살표2', '위쪽 스크롤 화살표Button2']
#    |    |    |    |    | child_window(title="위쪽 스크롤 화살표", auto_id="UpButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Thumb - '위치'    (L1251, T191, R1268, B263)
#    |    |    |    |    | ['위치3', '위치Thumb3', 'Thumb3']
#    |    |    |    |    | child_window(title="위치", auto_id="ScrollbarThumb", control_type="Thumb")
#    |    |    |    |    |
#    |    |    |    |    | Button - '페이지 아래로'    (L1251, T263, R1268, B266)
#    |    |    |    |    | ['Button11', '페이지 아래로Button2', '페이지 아래로2']
#    |    |    |    |    | child_window(title="페이지 아래로", auto_id="DownPageButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - '아래쪽 스크롤 화살표'    (L1251, T266, R1268, B283)
#    |    |    |    |    | ['Button12', '아래쪽 스크롤 화살표Button2', '아래쪽 스크롤 화살표2']
#    |    |    |    |    | child_window(title="아래쪽 스크롤 화살표", auto_id="DownButton", control_type="Button")
#    |    |    |    |
#    |    |    |    | ScrollBar - ''    (L146, T354, R1184, B371)
#    |    |    |    | [' 0 : 1 : 000ScrollBar', 'ScrollBar4']
#    |    |    |    | child_window(auto_id="1028", control_type="ScrollBar")
#    |    |    |    |    |
#    |    |    |    |    | Button - '왼쪽 스크롤 화살표'    (L146, T354, R163, B371)
#    |    |    |    |    | ['Button13', '왼쪽 스크롤 화살표2', '왼쪽 스크롤 화살표Button2']
#    |    |    |    |    | child_window(title="왼쪽 스크롤 화살표", auto_id="UpButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Thumb - '위치'    (L163, T354, R249, B371)
#    |    |    |    |    | ['위치4', '위치Thumb4', 'Thumb4']
#    |    |    |    |    | child_window(title="위치", auto_id="ScrollbarThumb", control_type="Thumb")
#    |    |    |    |    |
#    |    |    |    |    | Button - '페이지 오른쪽으로'    (L249, T354, R1167, B371)
#    |    |    |    |    | ['Button14', '페이지 오른쪽으로Button2', '페이지 오른쪽으로2']
#    |    |    |    |    | child_window(title="페이지 오른쪽으로", auto_id="DownPageButton", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - '오른쪽 스크롤 화살표'    (L1167, T354, R1184, B371)
#    |    |    |    |    | ['Button15', '오른쪽 스크롤 화살표2', '오른쪽 스크롤 화살표Button2']
#    |    |    |    |    | child_window(title="오른쪽 스크롤 화살표", auto_id="DownButton", control_type="Button")
#    |    |    |
#    |    |    | TitleBar - ''    (L24, T96, R1268, B118)
#    |    |    | ['TitleBar3', ' 0 : 1 : 000TitleBar']
#    |    |    |    |
#    |    |    |    | Menu - '시스템'    (L8, T96, R30, B118)
#    |    |    |    | ['시스템', '시스템Menu', 'Menu', '시스템0', '시스템1', '시스템Menu0', '시스템Menu1', 'Menu0', 'Menu1']
#    |    |    |    | child_window(title="시스템", auto_id="MenuBar", control_type="MenuBar")
#    |    |    |    |    |
#    |    |    |    |    | MenuItem - '시스템'    (L8, T96, R30, B118)
#    |    |    |    |    | ['MenuItem', '시스템MenuItem', '시스템2', 'MenuItem0', 'MenuItem1', '시스템MenuItem0', '시스템MenuItem1']
#    |    |    |    |    | child_window(title="시스템", control_type="MenuItem")
#    |    |    |    |
#    |    |    |    | Button - '최소화'    (L1166, T98, R1198, B116)
#    |    |    |    | ['Button16', '최소화Button', '최소화', '최소화Button0', '최소화Button1', '최소화0', '최소화1']
#    |    |    |    | child_window(title="최소화", control_type="Button")
#    |    |    |    |
#    |    |    |    | Button - '최대화'    (L1200, T98, R1232, B116)
#    |    |    |    | ['Button17', '최대화Button', '최대화']
#    |    |    |    | child_window(title="최대화", control_type="Button")
#    |    |    |    |
#    |    |    |    | Button - '닫기'    (L1234, T98, R1266, B116)
#    |    |    |    | ['Button18', '닫기2', '닫기Button2']
#    |    |    |    | child_window(title="닫기", control_type="Button")
#    |
#    | Pane - ''    (L649, T43, R864, B90)
#    | ['Pane4', 'BEATPane']
#    | child_window(auto_id="364", control_type="Pane")
#    |    |
#    |    | Static - 'CURSOR'    (L685, T51, R728, B63)
#    |    | ['Static2', 'CURSOR', 'CURSORStatic']
#    |    | child_window(title="CURSOR", auto_id="1327", control_type="Text")
#    |    |
#    |    | Static - 'QUANTIZE'    (L755, T51, R805, B63)
#    |    | ['QUANTIZEStatic', 'QUANTIZE', 'Static3']
#    |    | child_window(title="QUANTIZE", auto_id="1241", control_type="Text")
#    |    |
#    |    | Static - 'LENGTH'    (L810, T51, R850, B63)
#    |    | ['LENGTH', 'LENGTHStatic', 'Static4', 'LENGTH0', 'LENGTH1', 'LENGTHStatic0', 'LENGTHStatic1']
#    |    | child_window(title="LENGTH", auto_id="1242", control_type="Text")
#    |    |
#    |    | Static - 'LENGTH'    (L664, T68, R750, B83)
#    |    | ['LENGTH2', 'LENGTHStatic2', 'Static5']
#    |    | child_window(title="LENGTH", auto_id="1036", control_type="Text")
#    |    |
#    |    | Static - '1/16'    (L758, T68, R785, B83)
#    |    | ['1/16', 'Static6', '1/16Static', '1/160', '1/161', '1/16Static0', '1/16Static1']
#    |    | child_window(title="1/16", auto_id="1247", control_type="Text")
#    |    |
#    |    | Static - '1/16'    (L808, T68, R835, B83)
#    |    | ['1/162', 'Static7', '1/16Static2']
#    |    | child_window(title="1/16", auto_id="1152", control_type="Text")
#    |
#    | Pane - ''    (L189, T43, R651, B90)
#    | ['Pane5', 'SONG POS.Pane']
#    | child_window(auto_id="4003", control_type="Pane")
#    |    |
#    |    | Button - 'tool_gototop'    (L291, T54, R318, B81)
#    |    | ['Button19', 'tool_gototop', 'tool_gototopButton']
#    |    | child_window(title="tool_gototop", auto_id="1252", control_type="Button")
#    |    |
#    |    | Button - 'tool_backward'    (L320, T54, R347, B81)
#    |    | ['Button20', 'tool_backwardButton', 'tool_backward']
#    |    | child_window(title="tool_backward", auto_id="1253", control_type="Button")
#    |    |
#    |    | Button - 'tool_forward'    (L349, T54, R376, B81)
#    |    | ['Button21', 'tool_forward', 'tool_forwardButton']
#    |    | child_window(title="tool_forward", auto_id="1254", control_type="Button")
#    |    |
#    |    | Button - 'tool_gotoend'    (L378, T54, R405, B81)
#    |    | ['Button22', 'tool_gotoend', 'tool_gotoendButton']
#    |    | child_window(title="tool_gotoend", auto_id="1255", control_type="Button")
#    |    |
#    |    | Button - 'tool_play'    (L204, T54, R231, B81)
#    |    | ['Button23', 'tool_play', 'tool_playButton']
#    |    | child_window(title="tool_play", auto_id="1062", control_type="Button")
#    |    |
#    |    | Button - 'tool_stop'    (L233, T54, R260, B81)
#    |    | ['Button24', 'tool_stop', 'tool_stopButton']
#    |    | child_window(title="tool_stop", auto_id="1063", control_type="Button")
#    |    |
#    |    | Button - 'tool_loop'    (L262, T54, R289, B81)
#    |    | ['Button25', 'tool_loop', 'tool_loopButton']
#    |    | child_window(title="tool_loop", auto_id="1258", control_type="Button")
#    |    |
#    |    | Static - ' 0 : 1 : 000'    (L465, T68, R551, B83)
#    |    | ['Static8', ' 0 : 1 : 000', ' 0 : 1 : 000Static']
#    |    | child_window(title=" 0 : 1 : 000", auto_id="1256", control_type="Text")
#    |    |
#    |    | Static - '300.00'    (L556, T68, R599, B83)
#    |    | ['300.00', 'Static9', '300.00Static']
#    |    | child_window(title="300.00", auto_id="1257", control_type="Text")
#    |    |
#    |    | Static - '4/4'    (L604, T68, R647, B83)
#    |    | ['4/4Static', '4/4', 'Static10']
#    |    | child_window(title="4/4", auto_id="1259", control_type="Text")
#    |    |
#    |    | Static - 'TEMPO'    (L559, T51, R595, B63)
#    |    | ['TEMPO', 'TEMPOStatic', 'Static11']
#    |    | child_window(title="TEMPO", auto_id="1243", control_type="Text")
#    |    |
#    |    | Static - 'BEAT'    (L612, T51, R638, B63)
#    |    | ['BEAT', 'BEATStatic', 'Static12']
#    |    | child_window(title="BEAT", auto_id="1244", control_type="Text")
#    |    |
#    |    | Static - 'SONG POS.'    (L479, T51, R537, B63)
#    |    | ['SONG POS.', 'Static13', 'SONG POS.Static']
#    |    | child_window(title="SONG POS.", auto_id="1420", control_type="Text")
#    |    |
#    |    | Button - 'tool_startmaker'    (L407, T54, R434, B81)
#    |    | ['Button26', 'tool_startmaker', 'tool_startmakerButton']
#    |    | child_window(title="tool_startmaker", auto_id="33095", control_type="Button")
#    |    |
#    |    | Button - 'tool_endmaker'    (L436, T54, R463, B81)
#    |    | ['Button27', 'tool_endmakerButton', 'tool_endmaker']
#    |    | child_window(title="tool_endmaker", auto_id="33096", control_type="Button")
#    |
#    | Pane - ''    (L138, T43, R191, B90)
#    | ['Pane6']
#    | child_window(auto_id="669", control_type="Pane")
#    |    |
#    |    | Button - 'tool_pitch_render_'    (L153, T54, R180, B81)
#    |    | ['Button28', 'tool_pitch_render_', 'tool_pitch_render_Button']
#    |    | child_window(title="tool_pitch_render_", auto_id="1760", control_type="Button")
#    |
#    | Pane - ''    (L0, T43, R140, B90)
#    | ['Pane7']
#    | child_window(auto_id="4006", control_type="Pane")
#    |    |
#    |    | Button - 'tool_line'    (L73, T54, R100, B81)
#    |    | ['Button29', 'tool_lineButton', 'tool_line']
#    |    | child_window(title="tool_line", auto_id="33331", control_type="Button")
#    |    |
#    |    | Button - 'tool_eraser'    (L102, T54, R129, B81)
#    |    | ['Button30', 'tool_eraser', 'tool_eraserButton']
#    |    | child_window(title="tool_eraser", auto_id="33332", control_type="Button")
#    |    |
#    |    | Button - 'tool_arrow'    (L15, T54, R42, B81)
#    |    | ['Button31', 'tool_arrowButton', 'tool_arrow']
#    |    | child_window(title="tool_arrow", auto_id="33329", control_type="Button")
#    |    |
#    |    | Button - 'tool_pencil'    (L44, T54, R71, B81)
#    |    | ['Button32', 'tool_pencil', 'tool_pencilButton']
#    |    | child_window(title="tool_pencil", auto_id="33330", control_type="Button")
#    |
#    | TitleBar - ''    (L16, T-5, R1280, B23)
#    | ['TitleBar4']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-821ab154652d> in <module>
#      59     #vsqx.kill()
#      60     vsqx.set_focus()
# ---> 61     app.Dialog.print_control_identifiers()
#      62     pywinauto.keyboard.send_keys("%{F},{X}")
#      63
#
# ~\Anaconda3\lib\site-packages\pywinauto\application.py in print_control_identifiers(self, depth, filename)
#     687         if filename is None:
#     688             print("Control Identifiers:")
# --> 689             print_identifiers([this_ctrl, ])
#     690         else:
#     691             log_file = codecs.open(filename, "w", locale.getpreferredencoding())
#
# ~\Anaconda3\lib\site-packages\pywinauto\application.py in print_identifiers(ctrls, current_depth, log_func)
#     683                     log_func(output.encode(locale.getpreferredencoding(), errors='backslashreplace'))
#     684
# --> 685                 print_identifiers(ctrl.children(), current_depth + 1, log_func)
#     686
#     687         if filename is None:
#
# ~\Anaconda3\lib\site-packages\pywinauto\application.py in print_identifiers(ctrls, current_depth, log_func)
#     683                     log_func(output.encode(locale.getpreferredencoding(), errors='backslashreplace'))
#     684
# --> 685                 print_identifiers(ctrl.children(), current_depth + 1, log_func)
#     686
#     687         if filename is None:
#
# ~\Anaconda3\lib\site-packages\pywinauto\base_wrapper.py in children(self, **kwargs)
#     468         An empty list is returned if there are no children.
#     469         """
# --> 470         child_elements = self.element_info.children(**kwargs)
#     471         return [self.backend.generic_wrapper_class(element_info) for element_info in child_elements]
#     472
#
# ~\Anaconda3\lib\site-packages\pywinauto\uia_element_info.py in children(self, **kwargs)
#     281         cache_enable = kwargs.pop('cache_enable', False)
#     282         cond = IUIA().build_condition(**kwargs)
# --> 283         return self._get_elements(IUIA().tree_scope["children"], cond, cache_enable)
#     284
#     285     def iter_children(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pywinauto\uia_element_info.py in _get_elements(self, tree_scope, cond, cache_enable)
#     267         """Find all elements according to the given tree scope and conditions"""
#     268         try:
# --> 269             ptrs_array = self._element.FindAll(tree_scope, cond)
#     270             return elements_from_uia_array(ptrs_array, cache_enable)
#     271         except(COMError, ValueError):
#
# KeyboardInterrupt:
